# %%
import pandas as pd

# %%
top30_countries = ['United States', 'Spain', 'France', 'United Kingdom', 
                   'Germany', 'Italy', 'Thailand', 'Turkiye', 'Hong Kong SAR China', 
                   'Macao SAR, China', "China (People's Republic of)", 'Canada', 'Japan', 'Austria', 
                   'Netherlands', 'Malaysia', 'Mexico', 'Greece', 'United Arab Emirates', 
                   'Singapore' ,'Russian Federation', 'Poland', 'Saudi Arabia', 
                   'Croatia', 'South Africa', 'Denmark' ,'Czechia', 'Hungary', 
                   'Ukraine', 'Slovak Republic']

# %%
employement = pd.read_csv('./data/tourism_arrival_employment.csv')
employement
# Out:
#                country  year    arrivals  revenue_dollars   gdp_dollars  \
# 0     Macao SAR, China  2013  29325000.0     4.375500e+10  5.154000e+10
# 1     Macao SAR, China  2012  28082000.0     3.659300e+10  4.319000e+10
# 2     Macao SAR, China  2011  28002000.0     3.111800e+10  3.685000e+10
# 3     Macao SAR, China  2010  24965000.0     2.268800e+10  2.824000e+10
# 4     Macao SAR, China  2014  31526000.0     4.341200e+10  5.490000e+10
# ...                ...   ...         ...              ...           ...
# 3390            Zambia  2016    956000.0              NaN  2.096000e+10
# 3391            Zambia  2017   1009000.0              NaN  2.587000e+10
# 3392            Zambia  2018   1072000.0              NaN  2.631000e+10
# 3393            Zambia  2019   1266000.0              NaN  2.331000e+10
# 3394            Zambia  2020    502000.0              NaN  1.811000e+10
#
#       percent_of_gdp  entity  \
# 0          84.895227   Macao
# 1          84.725631   Macao
# ...

# %%
employement_topcountries = employement[employement['country'].isin(top30_countries)]

# %%
employement_topcountries['country'].unique()
# Out:
# array(['Macao SAR, China', 'Croatia', 'Thailand', 'Greece', 'Malaysia',
#        'United Arab Emirates', 'Singapore', 'Hungary', 'Austria', 'Spain',
#        'Turkiye', 'Ukraine', 'Czechia', 'Denmark', 'South Africa',
#        'Slovak Republic', 'Netherlands', 'Poland', 'France', 'Italy',
#        'Saudi Arabia', 'United Kingdom', 'Mexico', 'Canada', 'Germany',
#        'Russian Federation', 'United States', 'Japan',
#        "China (People's Republic of)"], dtype=object)

# %%
employement_topcountries.columns
# Out:
# Index(['country', 'year', 'arrivals', 'revenue_dollars', 'gdp_dollars',
#        'percent_of_gdp', 'entity',
#        'primary_energy_consumption_per_capita_kwh/person',
#        'annual_co2_emissions_per_capita)', 'code',
#        'accomodations_service_hotel', 'accomodation_service_other',
#        'food_beverage_serving', 'passenger_transport',
#        'travel_agency_and_other_resa', 'other_tourism_industry'],
#       dtype='object')

# %%
columns_to_convert = ['accomodations_service_hotel', 'accomodation_service_other',
       'food_beverage_serving', 'passenger_transport',
       'travel_agency_and_other_resa', 'other_tourism_industry']

def clean_and_convert(column):
    return column.str.replace('\u202f', '').str.replace(',', '').astype(float)

for column in columns_to_convert:
    employement_topcountries[column] = clean_and_convert(employement_topcountries[column])
# Out:
# /var/folders/m1/dk0h8kz11p9g8_szsqwqhdnc0000gn/T/ipykernel_15313/1311691378.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employement_topcountries[column] = clean_and_convert(employement_topcountries[column])
# /var/folders/m1/dk0h8kz11p9g8_szsqwqhdnc0000gn/T/ipykernel_15313/1311691378.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employement_topcountries[column] = clean_and_convert(employement_topcountries[column])
# ...

# %%
employement_topcountries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 0 to 3356
# Data columns (total 16 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   country                                           537 non-null    object
#  1   year                                              537 non-null    int64
#  2   arrivals                                          443 non-null    float64
#  3   revenue_dollars                                   514 non-null    float64
#  4   gdp_dollars                                       537 non-null    float64
#  5   percent_of_gdp                                    514 non-null    float64
#  6   entity                                            537 non-null    object
#  7   primary_energy_consumption_per_capita_kwh/person  537 non-null    float64
#  8   annual_co2_emissions_per_capita)                  537 non-null    float64
# ...

# %%
employement_topcountries[columns_to_convert] = employement_topcountries[columns_to_convert]*1000
# Out:
# /var/folders/m1/dk0h8kz11p9g8_szsqwqhdnc0000gn/T/ipykernel_15313/2322076601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employement_topcountries[columns_to_convert] = employement_topcountries[columns_to_convert]*1000

# %%
employement_topcountries.to_csv('./data_visu/03_employment/employment_topcountries.csv', index=False)

# %%
employement_topcountries = employement_topcountries[employement_topcountries['year']>=2004]

# %%
employement_topcountries
# Out:
#              country  year    arrivals  revenue_dollars   gdp_dollars  \
# 207          Croatia  2019  60021000.0     1.199417e+10  6.147000e+10
# 223          Croatia  2018  57668000.0     1.142533e+10  6.148000e+10
# 232          Croatia  2017  59238000.0     1.025417e+10  5.606000e+10
# 254          Croatia  2016  57587000.0     9.107381e+09  5.251000e+10
# 262          Croatia  2005  45762000.0     7.625000e+09  4.503000e+10
# ...              ...   ...         ...              ...           ...
# 3352  United Kingdom  2004  27755000.0              NaN  2.421530e+12
# 3353  United Kingdom  2005  29970000.0              NaN  2.543180e+12
# 3354  United Kingdom  2006  32713000.0              NaN  2.708440e+12
# 3355  United Kingdom  2007  32778000.0              NaN  3.090510e+12
# 3356  United Kingdom  2020  11101000.0              NaN  2.697810e+12
#
#       percent_of_gdp          entity  \
# 207        19.512235         Croatia
# 223        18.583814         Croatia
# ...
